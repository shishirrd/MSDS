# %% [markdown]
# # Assignment 3: Allstate – Insurance Policy & Claims Agent
# ### Shishir Deshpande, MSDS 442

# %%
import os
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from dotenv import load_dotenv

load_dotenv() # this will read my secrets and API keys from the .env file
os.environ["USER_AGENT"] = "MSDS442-Assignment2-Deshpande"

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.tools import tool
from langgraph.graph import StateGraph, END
from typing import TypedDict, Literal
from IPython.display import display, Markdown
model = ChatOpenAI(model="gpt-4o-mini", temperature=0) # Setting temperature to zero to ensure more deterministic outputs

# %% [markdown]
# 1. Use the LangChain/LangGraph framework to create an IPYNB script to build the graph of AI agents for Allstate who will coordinate, synchronize, and act to process insurance claims submitted by the customers.

# %% [markdown]
# 2. Create a graph using LangChain/LangGraph to capture the logic claim processing based on the following BPMN diagram (you must have an AI agent for every role/persona listed in the diagram):

# %% [markdown]
# ![Screenshot](image1.png)

# %% [markdown]
# 3. The insured person must enter the policy number and a picture of the car damage. Use policy number (999 876 543) and the following provided image for testing your AI Agents:

# %% [markdown]
# ![Screenshot2](image2.png)

# %% [markdown]
# 4. The policy verification agent will verify the entered policy number by the insured matches the policy record on file and the insured is not delinquent. The agent will use the following insurance policy declaration PDF document for verification of the policy number, effective date, and whether the insured is delinquent or not. If all checks pass the verification, the damage assessment agent will proceed to assess the damage; otherwise, the policy verification agent will send a claim denied notification to the insured.

# %% [markdown]
# ![Screenshot3](image3.png)

# %% [markdown]
# 5. After receiving the message that policy verification has passed from the policy verification agent, the insurance assessment agent will process the submitted image of the car damage and will generate the assessment report and payment amount that will be communicated back to the claim processing agent and claim payment agent.

# %% [markdown]
# 6. The claim processing agent must wait on the completion of payment authorization from the payment processing agent before sending a notification to the insured that the submitted claim is processed and approved.

# %% [markdown]
# 7. Provide 5 runs that will demonstrate a fully functional application for every scenario listed below:

# %% [markdown]
# - 7.1. The policy verification agent can recognize a delinquent insured.

# %% [markdown]
# - 7.2. The policy verification agent can recognize an invalid policy number entered by the insured.

# %% [markdown]
# - 7.3. The assessment agent can recognize and classify the damage from the image submitted by the insured for a major damage.

# %% [markdown]
# - 7.4. The assessment agent can recognize and classify the damage from the image submitted by the insured for a minor damage.

# %% [markdown]
# - 7.5. The assessment agent can recognize and classify the damage from the image submitted by the insured for a moderate damage.
